# %%
import pandas as pd
import numpy as np

# %%
#Carregamento e amostragem das primeiras linhas da dataframe


df_alunos = pd.read_csv(r"C:\Users\blood\Documents\bolsistas_2025.csv",low_memory=False)
display(df_alunos.head())
# Out:
#    Numero                       Aluno Bolsista             CPF  \
# 0       1   Alexandre de Jesus Valverde Júnior  ***.895.818-**
# 1       2  Ana Caroline Vasconcelos de Almeida  ***.800.556-**
# 2       3  Ana Clara Miranda Castro dos Santos  ***.697.036-**
# 3       4             Ana Lívia da Cruz Wiezel  ***.532.858-**
# 4       5                 Bárbara Beloti Silva  ***.587.328-**
#
#                                Curso  \
# 0           Geografia (Licenciatura)
# 1           ENFERMAGEM (Bacharelado)
# 2           Psicologia (Bacharelado)
# 3  TERAPIA OCUPACIONAL (Bacharelado)
# 4  Terapia ocupacional (Bacharelado)
#
#   Número de registro da atividade na PROEXT  \
# 0                                  276/2024
# 1                                  276/2024
# 2                                  276/2024
# 3                                  276/2024
# 4                                  276/2024
#
#                               Edital Valor mensal da bolsa  \
# 0  EDITAL Nº 08/2024/DAEN/DGE/PROENS              R$700,00
# 1  EDITAL Nº 08/2024/DAEN/DGE/PROENS              R$700,00
# 2  EDITAL Nº 08/2024/DAEN/DGE/PROENS              R$700,00
# 3  EDITAL Nº 08/2024/DAEN/DGE/PROENS              R$700,00
# 4  EDITAL Nº 08/2024/DAEN/DGE/PROENS              R$700,00
#
#   Período de recebimento da bolsa  \
# 0         01/08/2024 a 30/04/2026
# 1         01/08/2024 a 30/04/2026
# 2         01/08/2024 a 30/04/2026
# 3         01/08/2024 a 30/04/2026
# 4         01/08/2024 a 30/04/2026
#
#                                            Instituto
# 0  Coordenação-Geral de Planejamento, Orçamento e...
# 1                                      CGPO/SGTES/MS
# 2                                      CGPO/SGTES/MS
# 3                                      CGPO/SGTES/MS
# 4                                      CGPO/SGTES/MS

# %%
#Descrição estatística da dataframe 


display(df_alunos.describe())
# Out:
#            Numero
# count  110.000000
# mean    55.500000
# std     31.898276
# min      1.000000
# 25%     28.250000
# 50%     55.500000
# 75%     82.750000
# max    110.000000

# %%
# Tratamento de dados
#Criando uma cópia da dataframe e fazendo as modificações necessárias para facilitar a manipulação dos dados 

df_analise = df_alunos
df_analise = df_analise.drop(columns=['Numero'])
df_analise = df_analise.dropna()
df_analise['Curso'] = df_analise['Curso'].str.strip()
df_analise['Curso'] = df_analise['Curso'].str.title()
df_analise['Valor mensal da bolsa'] = df_analise['Valor mensal da bolsa'].str.strip('R$')
df_analise['Valor mensal da bolsa'] = df_analise['Valor mensal da bolsa'].str.strip('')
df_analise['Valor mensal da bolsa'] = df_analise['Valor mensal da bolsa'].str.replace(',','.')
df_analise['Valor mensal da bolsa'] = df_analise['Valor mensal da bolsa'].astype(float)


display(df_analise)
display(df_analise.info())
# Out:
#                           Aluno Bolsista             CPF  \
# 0     Alexandre de Jesus Valverde Júnior  ***.895.818-**
# 1    Ana Caroline Vasconcelos de Almeida  ***.800.556-**
# 2    Ana Clara Miranda Castro dos Santos  ***.697.036-**
# 3               Ana Lívia da Cruz Wiezel  ***.532.858-**
# 4                   Bárbara Beloti Silva  ***.587.328-**
# ..                                   ...             ...
# 105             Lucas Gabriel Alves Maia  ***.369.176-**
# 106         Maria Eduarda Gobbi Carvalho  ***.434.816-**
# 107                    Gabriel Fernandes  ***.089.348-**
# 108            Júlia Rodrigues de Castro  ***.548.331-**
# 109                Olivia Mello de Souza  ***.577.356-**
#
#                                    Curso  \
# 0               Geografia (Licenciatura)
# 1               Enfermagem (Bacharelado)
# 2               Psicologia (Bacharelado)
# 3      Terapia Ocupacional (Bacharelado)
# 4      Terapia Ocupacional (Bacharelado)
# ..                                   ...
# 105              Licenciatura Em Química
# 106  Licenciatura Em Ciências Biológicas
# 107                  Engenharia Elétrica
# 108                             Nutrição
# 109                           Psicologia
#
#     Número de registro da atividade na PROEXT  \
# 0                                    276/2024
# 1                                    276/2024
# 2                                    276/2024
# 3                                    276/2024
# 4                                    276/2024
# ..                                        ...
# 105                                  155/2021
# 106                                  156/2021
# 107                                   54/2021
# 108                                   61/2021
# 109                                   54/2021
#
#                                 Edital  Valor mensal da bolsa  \
# 0    EDITAL Nº 08/2024/DAEN/DGE/PROENS                  700.0
# 1    EDITAL Nº 08/2024/DAEN/DGE/PROENS                  700.0
# 2    EDITAL Nº 08/2024/DAEN/DGE/PROENS                  700.0
# 3    EDITAL Nº 08/2024/DAEN/DGE/PROENS                  700.0
# 4    EDITAL Nº 08/2024/DAEN/DGE/PROENS                  700.0
# ..                                 ...                    ...
# 105          PS Bolsistas CCCP 33/2025                  700.0
# 106          PS Bolsistas CCCP 33/2025                  700.0
# 107         PS Bolsistas CCult 34/2025                  700.0
# 108         PS Bolsistas CCult 34/2025                  700.0
# 109         PS Bolsistas CCult 34/2025                  700.0
#
#     Período de recebimento da bolsa  \
# 0           01/08/2024 a 30/04/2026
# 1           01/08/2024 a 30/04/2026
# 2           01/08/2024 a 30/04/2026
# 3           01/08/2024 a 30/04/2026
# 4           01/08/2024 a 30/04/2026
# ..                              ...
# 105          2025 - Maio a Dezembro
# 106          2025 - Maio a Dezembro
# 107          2025 - Maio a Dezembro
# 108          2025 - Maio a Dezembro
# 109          2025 - Maio a Dezembro
#
#                                              Instituto
# 0    Coordenação-Geral de Planejamento, Orçamento e...
# 1                                        CGPO/SGTES/MS
# 2                                        CGPO/SGTES/MS
# 3                                        CGPO/SGTES/MS
# 4                                        CGPO/SGTES/MS
# ..                                                 ...
# 105                                        PROEXT-UFTM
# 106                                        PROEXT-UFTM
# 107                                        PROEXT-UFTM
# 108                                        PROEXT-UFTM
# 109                                        PROEXT-UFTM
#
# [110 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 8 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Aluno Bolsista                             110 non-null    object
#  1   CPF                                        110 non-null    object
#  2   Curso                                      110 non-null    object
#  3   Número de registro da atividade na PROEXT  110 non-null    object
#  4   Edital                                     110 non-null    object
#  5   Valor mensal da bolsa                      110 non-null    float64
#  6   Período de recebimento da bolsa            110 non-null    object
#  7   Instituto                                  110 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 7.0+ KB
# None
